# %%
import pandas as pd

# %%
df = pd.read_json("./data/log_data/2018/11/2018-11-05-events.json", lines=True)

# %%
print(df)
# Out:
#               artist       auth firstName gender  itemInSession lastName  \
# 0      A Fine Frenzy  Logged In  Anabelle      F              0  Simpson
# 1            Nirvana  Logged In    Aleena      F              0    Kirby
# 2         Television  Logged In    Aleena      F              1    Kirby
# 3      JOHN COLTRANE  Logged In    Aleena      F              2    Kirby
# 4               NOFX  Logged In    Aleena      F              3    Kirby
# ..               ...        ...       ...    ...            ...      ...
# 403          Crystal  Logged In    Jayden      M              1      Fox
# 404  Plain White T S  Logged In  Theodore      M              0    Smith
# 405    Eddie Cochran  Logged In  Theodore      M              1    Smith
# 406             None  Logged In    Austin      M              0  Rosales
# 407    Justin Bieber  Logged In    Austin      M              1  Rosales
#
#         length level                                     location method  \
# ...

# %%
df = df[df['page'] == "NextSong"].astype({'ts': 'datetime64[ms]'})

# %%
print(df)
# Out:
#               artist       auth firstName gender  itemInSession lastName  \
# 0      A Fine Frenzy  Logged In  Anabelle      F              0  Simpson
# 1            Nirvana  Logged In    Aleena      F              0    Kirby
# 2         Television  Logged In    Aleena      F              1    Kirby
# 3      JOHN COLTRANE  Logged In    Aleena      F              2    Kirby
# 4               NOFX  Logged In    Aleena      F              3    Kirby
# ..               ...        ...       ...    ...            ...      ...
# 402  Vampire Weekend  Logged In    Jayden      M              0      Fox
# 403          Crystal  Logged In    Jayden      M              1      Fox
# 404  Plain White T S  Logged In  Theodore      M              0    Smith
# 405    Eddie Cochran  Logged In  Theodore      M              1    Smith
# 407    Justin Bieber  Logged In    Austin      M              1  Rosales
#
#         length level                                     location method  \
# ...

# %%
t = pd.Series(df['ts'], index=df.index)
# Out:
# 407

# %%
for data in t:
    print(type(data.weekofyear))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# ...
